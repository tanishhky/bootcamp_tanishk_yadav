# %% [markdown]
# # Data Acquisition: Stock Betas and Sector Information
# We will pull stock beta for each holding using the yfinance API and scrape S&P 500 sector data from Wikipedia. [cite: 117]

# %%
import pandas as pd
import yfinance as yf
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# --- 1. API Pull (yfinance) --- [cite: 119]
holdings_df = pd.read_csv('../../../project/data/raw/holdings.csv')
tickers = holdings_df['Ticker'].tolist()
stock_data = []

for ticker in tickers:
    stock = yf.Ticker(ticker)
    info = stock.info
    stock_data.append({
        'Ticker': ticker,
        'Beta': info.get('beta'),
        'Sector': info.get('sector'),
        'Market Cap': info.get('marketCap'),
        'Forward P/E': info.get('forwardPE')
    })

api_df = pd.DataFrame(stock_data)

# Validate the data [cite: 124]
print("API Data Validation:")
print(f"Shape: {api_df.shape}")
print(f"Missing Betas: {api_df['Beta'].isna().sum()}")

# Save the raw data [cite: 125]
timestamp = datetime.now().strftime("%Y%m%d-%H%M")
api_filename = f'../data/raw/api_BRK-Holdings_{timestamp}.csv'
api_df.to_csv(api_filename, index=False)
print(f"\nAPI data saved to {api_filename}")


# --- 2. Scrape a Small Table (Wikipedia) --- [cite: 126]
URL = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
response = requests.get(URL)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', {'id': 'constituents'})

scraped_df = pd.read_html(str(table))[0]
sectors_df = scraped_df[['Symbol', 'GICS Sector']]
sectors_df = sectors_df.rename(columns={'Symbol': 'Ticker'})

# Validate [cite: 129]
print("\nScraped Data Validation:")
print(f"Shape: {sectors_df.shape}")
print(f"Sectors found: {sectors_df['GICS Sector'].nunique()}")

# Save the raw data [cite: 130]
scrape_filename = f'../data/raw/scrape_Wikipedia_SP500-Sectors_{timestamp}.csv'
sectors_df.to_csv(scrape_filename, index=False)
print(f"\nScraped data saved to {scrape_filename}")
# Out:
# ---------------------------------------------------------------------------
# CurlError                                 Traceback (most recent call last)
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/curl_cffi/requests/session.py:640, in Session.request(self, method, url, params, data, json, headers, cookies, files, auth, timeout, allow_redirects, max_redirects, proxies, proxy, proxy_auth, verify, referer, accept_encoding, content_callback, impersonate, ja3, akamai, extra_fp, default_headers, default_encoding, quote, http_version, interface, cert, stream, max_recv_speed, multipart, discard_cookies)
#     639     else:
# --> 640         c.perform()
#     641 except CurlError as e:
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/curl_cffi/curl.py:365, in Curl.perform(self, clear_headers)
#     364 try:
# --> 365     self._check_error(ret, "perform")
#     366 finally:
#     367     # cleaning
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/curl_cffi/curl.py:187, in Curl._check_error(self, errcode, *args)
#     186 if error is not None:
# --> 187     raise error
#
# CurlError: Failed to perform, curl: (6) Could not resolve host: query1.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# The above exception was the direct cause of the following exception:
#
# DNSError                                  Traceback (most recent call last)
# Cell In[5], line 14
#      12 for ticker in tickers:
#      13     stock = yf.Ticker(ticker)
# ---> 14     info = stock.info
#      15     stock_data.append({
#      16         'Ticker': ticker,
#      17         'Beta': info.get('beta'),
#    (...)
#      20         'Forward P/E': info.get('forwardPE')
#      21     })
#      23 api_df = pd.DataFrame(stock_data)
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/ticker.py:163, in Ticker.info(self)
#     161 @property
#     162 def info(self) -> dict:
# --> 163     return self.get_info()
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/base.py:298, in TickerBase.get_info(self, proxy)
#     295     warnings.warn("Set proxy via new config function: yf.set_config(proxy=proxy)", DeprecationWarning, stacklevel=2)
#     296     self._data._set_proxy(proxy)
# --> 298 data = self._quote.info
#     299 return data
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/scrapers/quote.py:511, in Quote.info(self)
#     508 @property
#     509 def info(self) -> dict:
#     510     if self._info is None:
# --> 511         self._fetch_info()
#     512         self._fetch_complementary()
#     514     return self._info
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/scrapers/quote.py:610, in Quote._fetch_info(self)
#     608 self._already_fetched = True
#     609 modules = ['financialData', 'quoteType', 'defaultKeyStatistics', 'assetProfile', 'summaryDetail']
# --> 610 result = self._fetch(modules=modules)
#     611 additional_info = self._fetch_additional_info()
#     612 if additional_info is not None and result is not None:
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/scrapers/quote.py:590, in Quote._fetch(self, modules)
#     588 params_dict = {"modules": modules, "corsDomain": "finance.yahoo.com", "formatted": "false", "symbol": self._symbol}
#     589 try:
# --> 590     result = self._data.get_raw_json(_QUOTE_SUMMARY_URL_ + f"/{self._symbol}", params=params_dict)
#     591 except curl_cffi.requests.exceptions.HTTPError as e:
#     592     utils.get_yf_logger().error(str(e))
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/data.py:432, in YfData.get_raw_json(self, url, params, timeout)
#     430 def get_raw_json(self, url, params=None, timeout=30):
#     431     utils.get_yf_logger().debug(f'get_raw_json(): {url}')
# --> 432     response = self.get(url, params=params, timeout=timeout)
#     433     response.raise_for_status()
#     434     return response.json()
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/data.py:370, in YfData.get(self, url, params, timeout)
#     368 @utils.log_indent_decorator
#     369 def get(self, url, params=None, timeout=30):
# --> 370     return self._make_request(url, request_method = self._session.get, params=params, timeout=timeout)
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/data.py:391, in YfData._make_request(self, url, request_method, body, params, timeout)
#     388 if 'crumb' in params:
#     389     raise Exception("Don't manually add 'crumb' to params dict, let data.py handle it")
# --> 391 crumb, strategy = self._get_cookie_and_crumb()
#     392 if crumb is not None:
#     393     crumbs = {'crumb': crumb}
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/data.py:360, in YfData._get_cookie_and_crumb(self, timeout)
#     357         crumb = self._get_cookie_and_crumb_basic(timeout)
#     358 else:
#     359     # Fallback strategy
# --> 360     crumb = self._get_cookie_and_crumb_basic(timeout)
#     361     if crumb is None:
#     362         # Fail
#     363         self._set_cookie_strategy('csrf', have_lock=True)
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/data.py:241, in YfData._get_cookie_and_crumb_basic(self, timeout)
#     239 if not self._get_cookie_basic(timeout):
#     240     return None
# --> 241 return self._get_crumb_basic(timeout)
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/yfinance/data.py:224, in YfData._get_crumb_basic(self, timeout)
#     222     crumb_response = self._session.get(**get_args)
#     223 else:
# --> 224     crumb_response = self._session.get(**get_args)
#     225 self._crumb = crumb_response.text
#     226 if crumb_response.status_code == 429 or "Too Many Requests" in self._crumb:
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/curl_cffi/requests/session.py:661, in Session.get(self, url, **kwargs)
#     660 def get(self, url: str, **kwargs: Unpack[RequestParams]):
# --> 661     return self.request(method="GET", url=url, **kwargs)
#
# File /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages/curl_cffi/requests/session.py:647, in Session.request(self, method, url, params, data, json, headers, cookies, files, auth, timeout, allow_redirects, max_redirects, proxies, proxy, proxy_auth, verify, referer, accept_encoding, content_callback, impersonate, ja3, akamai, extra_fp, default_headers, default_encoding, quote, http_version, interface, cert, stream, max_recv_speed, multipart, discard_cookies)
#     645     rsp.request = req
#     646     error = code2error(e.code, str(e))
# --> 647     raise error(str(e), e.code, rsp) from e
#     648 else:
#     649     rsp = self._parse_response(
#     650         c, buffer, header_buffer, default_encoding, discard_cookies
#     651     )
#
# DNSError: Failed to perform, curl: (6) Could not resolve host: query1.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
